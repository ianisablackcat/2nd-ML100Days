# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    mse = sum((y-yp)**2) / len(y)
    
    return mse

# %%
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 231.893
# The Mean absolute error is 11.631

# %%
'''
作業一:
『請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：』
A: Store Item Demand Forecasting Challenge

1.你選的這組資料為何重要:
A:預測區域商品的銷售數量在商業行為上的重要性來自於，藉由此預測數量，可以推估該區域一系列相關
商業行為如倉儲、物流運輸、商品陳列、人力支援、行銷活動、銷售額......等相關事項的數據，以作為後續運營依據。

2.資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集):
A:推測為Kaggle自行隨機產生之數據資料。

3.蒐集而來的資料型態為何:
A:為csv檔裡包含了五年的五十項商品在十間不同店鋪的每日銷售數量。

4.這組資料想解決的問題如何評估:
A:這組資料想預測未來三個月的商品銷售數量，並使用SMAPE指標來判斷準確度。銷售數量可用趨勢預測分析(算術平均、移動加權、指數平滑)和
因果預測分析(迴歸分析)及時間序列分析，由於此份資料並未給除了銷售數據之外的資料因此不適用因果分析。

作業二:
想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

1.核心問題為何 (tips：如何定義 「提升業績 & 你的假設」):
A:「提升業績」可定義為提升每日營業額，可以每部車的當日載客總金額視之，更細部可以平均每車每工作小時的載客金額、載客區域、載客時段
(日間、夜間)等討論之。假設載客來源可分為路邊隨機載客及預約載送，客戶群可分為一般客及商務客，地點又可區分為住宅區、商業區、特殊地
點(車站、醫院、飯店、市集等)，其中預約載送優於隨機載客，商務客優於一般客，商業區及特殊地點優於住宅區。

2.資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集):
A:每日每車的行走路線、上下客時間地點金額、客人的分類皆可作為資料分析的依據。資料蒐集的來源依賴於每車的GPS定位系統可記錄行車路線，
並固定紀錄每位客人的消費紀錄，時間、地點、金額，還有客戶的分類，隨機招停或是預約載送，甚至天氣、路況、事件皆可記錄做輔佐分析。

3.蒐集而來的資料型態為何:
A:蒐集來的資料會包含了數據及非數據資料，為連續的時間序列。

4.你要回答的問題，其如何評估 (tips：你的假設如何驗證):
A:可依假設的各項分類對數據做分類討論，同時可輔以決策樹分析。
'''
